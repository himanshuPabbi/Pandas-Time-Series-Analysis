# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("apple.csv")

# %%
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0     7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 1     6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2     5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 3     3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 4    30-Jun-17  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246  15-Jul-16   98.92   99.30   98.50   98.78  30136990
# 247  14-Jul-16   97.39   98.99   97.32   98.79  38918997
# 248  13-Jul-16   97.41   97.67   96.84   96.87  25892171
# 249  12-Jul-16   97.17   97.70   97.12   97.42  24167463
# 250  11-Jul-16   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    251 non-null    object
#  1   Open    251 non-null    float64
#  2   High    251 non-null    float64
#  3   Low     251 non-null    float64
#  4   Close   251 non-null    float64
#  5   Volume  251 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 11.9+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1   2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2   2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3   2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4   2017-06-30  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 247 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 248 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 249 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 250 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
df.index=df['Date']

# %%
df
# Out:
#                  Date    Open    High     Low   Close    Volume
# Date
# 2017-07-07 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...               ...     ...     ...     ...     ...       ...
# 2016-07-15 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %% [markdown]
# # Data for Jan

# %%
df['2017-01']
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_22960\1372776413.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-01']
#                  Date    Open    High     Low   Close    Volume
# Date
# 2017-01-31 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19 2017-01-19  119.40  120.09  119.37  119.78  25597291
# ...

# %%
df['2017-01'].Close
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_22960\3958561618.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-01'].Close
# Date
# 2017-01-31    121.35
# 2017-01-30    121.63
# 2017-01-27    121.95
# 2017-01-26    121.94
# 2017-01-25    121.88
# 2017-01-24    119.97
# 2017-01-23    120.08
# 2017-01-20    120.00
# 2017-01-19    119.78
# 2017-01-18    119.99
# 2017-01-17    120.00
# 2017-01-13    119.04
# 2017-01-12    119.25
# 2017-01-11    119.75
# 2017-01-10    119.11
# 2017-01-09    118.99
# 2017-01-06    117.91
# 2017-01-05    116.61
# 2017-01-04    116.02
# 2017-01-03    116.15
# Name: Close, dtype: float64

# %%
df['2017-01'].Close.mean()
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_22960\1481154476.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-01'].Close.mean()
# 119.57000000000001

# %%
df['2017']
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_22960\1797912031.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017']
#                  Date    Open    High     Low   Close    Volume
# Date
# 2017-07-07 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...               ...     ...     ...     ...     ...       ...
# 2017-01-09 2017-01-09  117.95  119.43  117.94  118.99  33561948
# 2017-01-06 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05 2017-01-05  115.92  116.86  115.81  116.61  22193587
# ...

# %%
df['2017-01':'2017-06']
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_22960\3473155483.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df['2017-01':'2017-06']
#                  Date    Open    High     Low   Close    Volume
# Date
# 2017-06-30 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-06-29 2017-06-29  144.71  145.13  142.28  143.68  31499368
# 2017-06-28 2017-06-28  144.49  146.11  143.16  145.83  22082432
# 2017-06-27 2017-06-27  145.01  146.16  143.62  143.73  24761891
# 2017-06-26 2017-06-26  147.17  148.28  145.38  145.82  25692361
# ...               ...     ...     ...     ...     ...       ...
# 2017-01-09 2017-01-09  117.95  119.43  117.94  118.99  33561948
# 2017-01-06 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04 2017-01-04  115.85  116.51  115.75  116.02  21118116
# ...

# %% [markdown]
# # Monthly Average Close price

# %%
df.Close.resample("M").mean()
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
df.Close.resample("M").mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.resample('W').mean()
# Out:
# Date
# 2016-07-17     97.7680
# 2016-07-24     99.5500
# 2016-07-31    101.1020
# 2016-08-07    105.9340
# 2016-08-14    108.2580
# 2016-08-21    109.3040
# 2016-08-28    107.9800
# 2016-09-04    106.6760
# 2016-09-11    106.1775
# 2016-09-18    111.1300
# 2016-09-25    113.6060
# 2016-10-02    113.0300
# 2016-10-09    113.3040
# 2016-10-16    116.8600
# 2016-10-23    117.1600
# 2016-10-30    115.9380
# 2016-11-06    111.0580
# 2016-11-13    109.7140
# 2016-11-20    108.5640
# 2016-11-27    111.6375
# 2016-12-04    110.5880
# 2016-12-11    111.2320
# 2016-12-18    115.0940
# 2016-12-25    116.6920
# 2017-01-01    116.6425
# 2017-01-08    116.6725
# 2017-01-15    119.2280
# 2017-01-22    119.9425
# 2017-01-29    121.1640
# 2017-02-05    125.8680
# 2017-02-12    131.6800
# 2017-02-19    134.9760
# 2017-02-26    136.7500
# 2017-03-05    138.4900
# 2017-03-12    139.1360
# 2017-03-19    139.8660
# 2017-03-26    140.8560
# 2017-04-02    143.2780
# 2017-04-09    143.8980
# ...

# %%
df.Close.resample('W').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.resample('Q').mean()
# Out:
# Date
# 2016-09-30    106.718644
# 2016-12-31    113.399048
# 2017-03-31    131.712419
# 2017-06-30    147.875397
# 2017-09-30    143.625000
# Freq: Q-DEC, Name: Close, dtype: float64

# %%
df.Close.resample('Q').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.resample('B').mean()
# Out:
# Date
# 2016-07-11     96.98
# 2016-07-12     97.42
# 2016-07-13     96.87
# 2016-07-14     98.79
# 2016-07-15     98.78
#                ...
# 2017-07-03    143.50
# 2017-07-04       NaN
# 2017-07-05    144.09
# 2017-07-06    142.73
# 2017-07-07    144.18
# Freq: B, Name: Close, Length: 260, dtype: float64

# %%
df.Close.resample('B').mean().plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.resample('MS').mean()
# Out:
# Date
# 2016-07-01     99.473333
# 2016-08-01    107.665217
# 2016-09-01    110.857143
# 2016-10-01    115.707143
# 2016-11-01    110.154286
# 2016-12-01    114.335714
# 2017-01-01    119.570000
# 2017-02-01    133.713684
# 2017-03-01    140.617826
# 2017-04-01    142.886842
# 2017-05-01    152.227727
# 2017-06-01    147.831364
# 2017-07-01    143.625000
# Freq: MS, Name: Close, dtype: float64

# %%
df.Close.resample('MS').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.resample('QS').mean()
# Out:
# Date
# 2016-07-01    106.718644
# 2016-10-01    113.399048
# 2017-01-01    131.712419
# 2017-04-01    147.875397
# 2017-07-01    143.625000
# Freq: QS-JAN, Name: Close, dtype: float64

# %%
df.Close.resample('QS').plot()
# Out:
# Date
# 2016-07-01    AxesSubplot(0.125,0.2;0.775x0.68)
# 2016-10-01    AxesSubplot(0.125,0.2;0.775x0.68)
# 2017-01-01    AxesSubplot(0.125,0.2;0.775x0.68)
# 2017-04-01    AxesSubplot(0.125,0.2;0.775x0.68)
# 2017-07-01    AxesSubplot(0.125,0.2;0.775x0.68)
# Freq: QS-JAN, Name: Close, dtype: object

# %%
df.Close.resample('A').mean()
#Year End
# Out:
# Date
# 2016-12-31    110.168361
# 2017-12-31    139.975349
# Freq: A-DEC, Name: Close, dtype: float64

# %%
df.Close.resample('A').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df=pd.read_csv("apple_no_date.csv")

# %%
df
# Out:
#        Open    High     Low   Close    Volume
# 0    142.90  144.75  142.90  144.18  19201712
# 1    143.02  143.50  142.41  142.73  24128782
# 2    143.69  144.79  142.72  144.09  21569557
# 3    144.88  145.30  143.10  143.50  14277848
# 4    144.45  144.96  143.78  144.02  23024107
# ..      ...     ...     ...     ...       ...
# 246   98.92   99.30   98.50   98.78  30136990
# 247   97.39   98.99   97.32   98.79  38918997
# 248   97.41   97.67   96.84   96.87  25892171
# 249   97.17   97.70   97.12   97.42  24167463
# 250   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
rng=pd.date_range(start="2016-07-07",end="2017-07-07",freq='B')

# %%
rng
# Out:
# DatetimeIndex(['2016-07-07', '2016-07-08', '2016-07-11', '2016-07-12',
#                '2016-07-13', '2016-07-14', '2016-07-15', '2016-07-18',
#                '2016-07-19', '2016-07-20',
#                ...
#                '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29',
#                '2017-06-30', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-07'],
#               dtype='datetime64[ns]', length=262, freq='B')

# %%
rng=rng[:251]

# %%
df.set_index(rng,inplace=True)

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# 2016-07
2016-07-13', '2016-07-14', '2016-07-15', '2016-07-18',
#                '2016-07-19', '2016-07-20', '2016-07-21', '2016-07-22',
#                '2016-07-25', '2016-07-26', '2016-07-27', '2016-07-28',
#                '2016-07-29', '2016-08-01', '2016-08-02', '2016-08-03',
#                '2016-08-04', '2016-08-05', '2016-08-08', '2016-08-09',
#                '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-15',
#                '2016-08-16', '2016-08-17', '2016-08-18', '2016-08-19',
#                '2016-08-22', '2016-08-23', '2016-08-24', '2016-08-25',
#                '2016-08-26', '2016-08-29', '2016-08-30', '2016-08-31',
#                '2016-09-01', '2016-09-02', '2016-09-05', '2016-09-06',
#                '2016-09-07', '2016-09-08', '2016-09-09', '2016-09-12',
#                '2016-09-13', '2016-09-14', '2016-09-15', '2016-09-16',
# ...

# %%
rng=pd.date_range(start="2016-07-07",periods=72,freq='H')

# %%
rng
# Out:
# DatetimeIndex(['2016-07-07 00:00:00', '2016-07-07 01:00:00',
#                '2016-07-07 02:00:00', '2016-07-07 03:00:00',
#                '2016-07-07 04:00:00', '2016-07-07 05:00:00',
#                '2016-07-07 06:00:00', '2016-07-07 07:00:00',
#                '2016-07-07 08:00:00', '2016-07-07 09:00:00',
#                '2016-07-07 10:00:00', '2016-07-07 11:00:00',
#                '2016-07-07 12:00:00', '2016-07-07 13:00:00',
#                '2016-07-07 14:00:00', '2016-07-07 15:00:00',
#                '2016-07-07 16:00:00', '2016-07-07 17:00:00',
#                '2016-07-07 18:00:00', '2016-07-07 19:00:00',
#                '2016-07-07 20:00:00', '2016-07-07 21:00:00',
#                '2016-07-07 22:00:00', '2016-07-07 23:00:00',
#                '2016-07-08 00:00:00', '2016-07-08 01:00:00',
#                '2016-07-08 02:00:00', '2016-07-08 03:00:00',
#                '2016-07-08 04:00:00', '2016-07-08 05:00:00',
# ...

# %%
import numpy as np

# %%
np.random.randint(1,10,size=len(rng))
# Out:
# array([3, 7, 2, 6, 1, 6, 2, 1, 8, 8, 7, 6, 1, 8, 3, 3, 5, 2, 5, 2, 6, 3,
#        9, 7, 1, 1, 5, 3, 8, 9, 7, 7, 3, 1, 9, 8, 9, 2, 3, 3, 4, 3, 9, 8,
#        2, 5, 8, 8, 1, 7, 2, 5, 1, 1, 1, 3, 7, 9, 9, 2, 8, 7, 7, 3, 2, 4,
#        3, 8, 1, 8, 8, 5])

# %%
ts=pd.Series(np.random.randint(1,10,len(rng)),index=rng)

# %%
ts
#usefull in random sample
# Out:
# 2016-07-07 00:00:00    9
# 2016-07-07 01:00:00    3
# 2016-07-07 02:00:00    9
# 2016-07-07 03:00:00    5
# 2016-07-07 04:00:00    4
#                       ..
# 2016-07-09 19:00:00    4
# 2016-07-09 20:00:00    4
# 2016-07-09 21:00:00    1
# 2016-07-09 22:00:00    2
# 2016-07-09 23:00:00    3
# Freq: H, Length: 72, dtype: int32
